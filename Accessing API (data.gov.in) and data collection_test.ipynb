# %%
#Importing all the required packages
import pandas as pd
import requests 
import io

# %%
#We create a new variable “urlData”, where we fetch the data from the API using the get() from the Requests Python package.
#Here I have preffered to go with "CSV" file as there might be huge volume of data
url_data = requests.get("https://api.data.gov.in/resource/3b01bcb8-0b14-4abf-b6f2-c1bfd384ba69?api-key=579b464db66ec23bdd000001fc815e771f3a46e162d44e8e5b3ff2ab&format=csv&offset=0&limit=2000")

# %%
print(url_data)
# Out:
# <Response [200]>

# %% [markdown]
# **You also get an option to choose the limit to the data which is fetched when you call the API, which in this case has been set to 2000 (since there are approx. 1240 stations around India from where we get the data, so basically on every call we request 1240 rows of data). [CPCB](https://cpcb.nic.in/), This is India's central pollution control board, were can you find the collection centres and where they are located.**

# %%
#To cross check if our request fetches the data(the actual content) or not
#This is a CSV file type as we requested CSV in our request
print(url_data.content)
# Out:
# b'id,country,state,city,station,last_update,pollutant_id,pollutant_min,pollutant_max,pollutant_avg,pollutant_unit\n1,India,Andhra_Pradesh,Anantapur,"Gulzarpet, Anantapur - APPCB","23-08-2022 16:00:00",PM2.5,NA,NA,NA,NA\n2,India,Andhra_Pradesh,Anantapur,"Gulzarpet, Anantapur - APPCB","23-08-2022 16:00:00",PM10,NA,NA,NA,NA\n3,India,Andhra_Pradesh,Anantapur,"Gulzarpet, Anantapur - APPCB","23-08-2022 16:00:00",NO2,NA,NA,NA,NA\n4,India,Andhra_Pradesh,Anantapur,"Gulzarpet, Anantapur - APPCB","23-08-2022 16:00:00",NH3,NA,NA,NA,NA\n5,India,Andhra_Pradesh,Anantapur,"Gulzarpet, Anantapur - APPCB","23-08-2022 16:00:00",SO2,NA,NA,NA,NA\n6,India,Andhra_Pradesh,Anantapur,"Gulzarpet, Anantapur - APPCB","23-08-2022 16:00:00",CO,16,40,35,NA\n7,India,Andhra_Pradesh,Anantapur,"Gulzarpet, Anantapur - APPCB","23-08-2022 16:00:00",OZONE,13,30,24,NA\n8,India,Andhra_Pradesh,Rajamahendravaram,"Anand Kala Kshetram, Rajamahendravaram - APPCB","23-08-2022 16:00:00",PM2.5,10,44,20,NA\n9,India,Andhra_Pradesh,Raja
# ...

# %%
#Using .content in the same request command to get the content along with the results
url_data = requests.get("https://api.data.gov.in/resource/3b01bcb8-0b14-4abf-b6f2-c1bfd384ba69?api-key=579b464db66ec23bdd000001fc815e771f3a46e162d44e8e5b3ff2ab&format=csv&offset=0&limit=2000").content

# %%
#Reading the results from the API call.
#Using the StringIO method to set as file object. Now we have an object file that we will able to treat just like a file.
df = pd.read_csv(io.StringIO(url_data.decode('utf-8')))

# %%
df.head()
# Out:
#    id country           state       city                       station  \
# 0   1   India  Andhra_Pradesh  Anantapur  Gulzarpet, Anantapur - APPCB
# 1   2   India  Andhra_Pradesh  Anantapur  Gulzarpet, Anantapur - APPCB
# 2   3   India  Andhra_Pradesh  Anantapur  Gulzarpet, Anantapur - APPCB
# 3   4   India  Andhra_Pradesh  Anantapur  Gulzarpet, Anantapur - APPCB
# 4   5   India  Andhra_Pradesh  Anantapur  Gulzarpet, Anantapur - APPCB
#
#            last_update pollutant_id  pollutant_min  pollutant_max  \
# 0  23-08-2022 18:00:00        PM2.5            NaN            NaN
# 1  23-08-2022 18:00:00         PM10            NaN            NaN
# 2  23-08-2022 18:00:00          NO2            NaN            NaN
# 3  23-08-2022 18:00:00          NH3            NaN            NaN
# 4  23-08-2022 18:00:00          SO2            NaN            NaN
#
#    pollutant_avg  pollutant_unit
# 0            NaN             NaN
# 1            NaN             NaN
# 2            NaN             NaN
# ...

# %%
#As we have limited our number of results to 2000 the len of df 20000
len(df)
# Out:
# 2000
